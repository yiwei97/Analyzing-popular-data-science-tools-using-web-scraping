# %%
# Install packages
import pandas as pd

# Read packages
df = pd.read_csv('../1_Data_extraction/Output/job_offers.csv')

# %%
df.head()
# Out:
#                                         job_title  \
# 0                      Senior Carbon Data Analyst
# 1  Senior Security Engineer (Penetration Testing)
# 2                          Senior Data Specialist
# 3              Research Assistant/Engineer (SKJ5)
# 4                            Data Engineer Intern
#
#                         company_name      company_location work_method  \
# 0            Unravel Carbon (YC W22)  Singapore, Singapore     On-site
# 1             Infosys Compaz Pte Ltd  Singapore, Singapore     On-site
# 2                            Singtel  Singapore, Singapore      Hybrid
# 3  Singapore Institute of Technology  Singapore, Singapore      Hybrid
# 4                             KNOREX  Singapore, Singapore     On-site
#
#       post_date no_of_applicants                     work_time  \
# 0   3 weeks ago   119 applicants  Full-time · Mid-Senior level
# 1  3 months ago    22 applicants  Full-time · Mid-Senior level
# ...
